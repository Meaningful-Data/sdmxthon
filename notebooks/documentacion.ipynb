# %%
import sqlite3
import pandas as pd
import sdmxthon
from sdmxthon.model.dataset import Dataset
from sdmxthon.model.itemScheme import Concept
from sdmxthon.model.component import Dimension
from sdmxthon.model.base import LocalisedString, InternationalString

# %% [markdown]
# ### Defining files and path to DB and URL to Fusion Registry

# %%
pathTestXS = 'sdmxthon/outputTests/test_XS.xml'
pathToDB = 'sdmxthon/outputTests/BIS_DER_OUTS.db'
pathToData = 'sdmxthon/outputTests/BIS_DER_DATAFLOW.xml'
pathMetadata = 'cbd_dsd.sdmx'


urlECB = 'http://ec.europa.eu/eurostat/SDMX/diss-web/rest/data/nama_10_gdp/.CLV10_MEUR.B1GQ.BE/?startperiod=2005&endPeriod=2011'
urlMetadata = 'http://fusionregistry.meaningfuldata.eu/MetadataRegistry/ws/public/sdmxapi/rest/datastructure/BIS/BIS_DER/latest/?format=sdmx-2.1&detail=full&references=all&prettyPrint=true'

# %% [markdown]
# ### Reading an SDMX file

# %%
message = sdmxthon.read_sdmx(pathMetadata)
print(message.type)
# Out:
# MessageTypeEnum.Metadata

# %%
message.payload.dsds
# Out:
# {'ECB:ECB_CBD2(1.0)': <DataStructureDefinition  - ECB:ECB_CBD2(1.0)>}

# %%
message.content
# Out:
# {'codelists': {'ECB:CL_ACTIVITY(1.0)': <Codelist - CL_ACTIVITY>,
#   'ECB:CL_AREA(1.0)': <Codelist - CL_AREA>,
#   'ECB:CL_CB_EXP_TYPE(1.0)': <Codelist - CL_CB_EXP_TYPE>,
#   'ECB:CL_CB_ITEM(1.0)': <Codelist - CL_CB_ITEM>,
#   'ECB:CL_CB_PORTFOLIO(1.0)': <Codelist - CL_CB_PORTFOLIO>,
#   'ECB:CL_CB_REP_FRAMEWRK(1.0)': <Codelist - CL_CB_REP_FRAMEWRK>,
#   'ECB:CL_CB_REP_SECTOR(1.0)': <Codelist - CL_CB_REP_SECTOR>,
#   'ECB:CL_CB_SECTOR_SIZE(1.0)': <Codelist - CL_CB_SECTOR_SIZE>,
#   'ECB:CL_CB_VAL_METHOD(1.0)': <Codelist - CL_CB_VAL_METHOD>,
#   'ECB:CL_CONF_STATUS(1.0)': <Codelist - CL_CONF_STATUS>,
#   'ECB:CL_CURRENCY(1.0)': <Codelist - CL_CURRENCY>,
#   'ECB:CL_DECIMALS(1.0)': <Codelist - CL_DECIMALS>,
#   'ECB:CL_FREQ(1.0)': <Codelist - CL_FREQ>,
#   'ECB:CL_FSENTRY(1.0)': <Codelist - CL_FSENTRY>,
#   'ECB:CL_MATURITY(1.0)': <Codelist - CL_MATURITY>,
#   'ECB:CL_OBS_STATUS(1.0)': <Codelist - CL_OBS_STATUS>,
#   'ECB:CL_ORGANISATION(1.0)': <Codelist - CL_ORGANISATION>,
#   'ECB:CL_SECTOR(1.0)': <Codelist - CL_SECTOR>,
#   'ECB:CL_TIME_COLLECT(1.0)': <Codelist - CL_TIME_COLLECT>,
#   'ECB:CL_UNIT(1.0)': <Codelist - CL_UNIT>,
#   'ECB:CL_UNIT_MULT(1.0)': <Codelist - CL_UNIT_MULT>},
#  'concepts': {'ECB:ECB_CONCEPTS(1.0)': <ConceptScheme - ECB:ECB_CONCEPTS(1.0)>},
#  'dsds': {'ECB:ECB_CBD2(1.0)': <DataStructureDefinition  - ECB:ECB_CBD2(1.0)>},
#  'organisations': <AgencyScheme - SDMX:AGENCIES(1.0)>}

# %% [markdown]
# ### Read data from SDMX file

# %%
data_message = sdmxthon.read_sdmx(urlECB)

# %%
data_message.content['datasets']['ESTAT_DSD_nama_10_gdp_1_0'].data
# Out:
#   NA_ITEM        UNIT GEO FREQ TIME_PERIOD OBS_VALUE
# 0    B1GQ  CLV10_MEUR  BE    A        2011  369293.6
# 1    B1GQ  CLV10_MEUR  BE    A        2010  363140.1
# 2    B1GQ  CLV10_MEUR  BE    A        2009  353028.3
# 3    B1GQ  CLV10_MEUR  BE    A        2008  360309.3
# 4    B1GQ  CLV10_MEUR  BE    A        2007  358706.1
# 5    B1GQ  CLV10_MEUR  BE    A        2006  345984.7
# 6    B1GQ  CLV10_MEUR  BE    A        2005  337373.7

# %% [markdown]
# ### Read data from DB and create SDMX file

# %%
conn = sqlite3.connect(pathToDB)
df = pd.read_sql('SELECT * from BIS_DER WHERE DER_TYPE = "U" and DER_RISK = "D";', conn)
df
# Out:
#        FREQ DER_TYPE DER_INSTR DER_RISK DER_REP_CTY DER_SECTOR_CPY DER_CPC  \
# 0         A        U         8        D          5J              A      1E
# 1         A        U         8        D          5J              A      1E
# 2         A        U         8        D          5J              A      1E
# 3         A        U         8        D          5J              A      1E
# 4         A        U         8        D          5J              A      1E
# ...     ...      ...       ...      ...         ...            ...     ...
# 164097    A        U         Z        D          US              C      5Z
# 164098    A        U         Z        D          US              U      1E
# 164099    A        U         Z        D          US              U      5J
# 164100    A        U         Z        D          US              U      5Z
# 164101    A        U         Z        D          ZA              A      5J
#
#        DER_SECTOR_UDL DER_CURR_LEG1 DER_CURR_LEG2  ... DECIMALS UNIT_MEASURE  \
# 0                   A           AED           TO1  ...        3          USD
# 1                   A           ARS           TO1  ...        3          USD
# 2                   A           AUD           TO1  ...        3          USD
# 3                   A           BGN           TO1  ...        3          USD
# 4                   A           BHD           TO1  ...        3          USD
# ...               ...           ...           ...  ...      ...          ...
# 164097              A           TO1           TO1  ...        3          USD
# 164098              A           TO1           TO1  ...        3          USD
# 164099              A           TO1           TO1  ...        3          USD
# 164100              A           TO1           TO1  ...        3          USD
# 164101              A           TO1           TO1  ...        3          USD
#
#        UNIT_MULT TIME_FORMAT  AVAILABILITY  COLLECTION  TITLE_TS OBS_STATUS  \
# 0              6        None             K           S      None          A
# 1              6        None             K           S      None          A
# 2              6        None             K           S      None          A
# 3              6        None             K           S      None          A
# 4              6        None             K           S      None          A
# ...          ...         ...           ...         ...       ...        ...
# 164097         6        None             K           S      None          A
# 164098         6        None             K           S      None          A
# 164099         6        None             K           S      None          A
# 164100         6        None             K           S      None          A
# 164101         6        None             K           S      None          A
#
#         OBS_CONF OBS_PRE_BREAK
# 0              F          None
# 1              F          None
# 2              F          None
# 3              F          None
# 4              F          None
# ...          ...           ...
# 164097         F          None
# 164098         F          None
# 164099         F          None
# 164100         F          None
# 164101         F          None
#
# [164102 rows x 26 columns]

# %%
message = sdmxthon.read_sdmx(urlMetadata)

dataset2 = Dataset(message.payload.dsds["BIS:BIS_DER(1.0)"], data=df)
print(dataset2)
# Out:
# <DataSet  - BIS_DER>

# %%
errors = dataset2.semantic_validation()

print(errors)
# Out:
# []

# %%
dataset2.data['FREQ'] = 'Z'
errors = dataset2.semantic_validation()

print(errors)
# Out:
# [{'Code': 'SS04', 'ErrorLevel': 'CRITICAL', 'Component': 'FREQ', 'Type': 'Dimension', 'Rows': None, 'Message': 'Wrong value Z for dimension FREQ'}]

# %%
dataset2.set_dimension_at_observation('TIME_PERIOD')
dataset2.to_xml(sdmxthon.MessageTypeEnum.StructureDataSet, pathTestXS)

# %% [markdown]
# ### Metadata navigation

# %%
concept_scheme = message.content['concepts']["ECB:ECB_CONCEPTS(1.0)"]
concept_scheme.items
# Out:
# {'ACCOUNT_ENTRY': <Concept - ACCOUNT_ENTRY>,
#  'ADJU_DETAIL': <Concept - ADJU_DETAIL>,
#  'ADJUST_DETAIL': <Concept - ADJUST_DETAIL>,
#  'ADJUSTMENT': <Concept - ADJUSTMENT>,
#  'AGG_EQUN': <Concept - AGG_EQUN>,
#  'AME_AGG_METHOD': <Concept - AME_AGG_METHOD>,
#  'AME_ITEM': <Concept - AME_ITEM>,
#  'AME_REF_AREA': <Concept - AME_REF_AREA>,
#  'AME_REFERENCE': <Concept - AME_REFERENCE>,
#  'AME_TRANSFORMATION': <Concept - AME_TRANSFORMATION>,
#  'AME_UNIT': <Concept - AME_UNIT>,
#  'AMOUNT_CAT': <Concept - AMOUNT_CAT>,
#  'AREA_DEFINITION': <Concept - AREA_DEFINITION>,
#  'AVAILABILITY': <Concept - AVAILABILITY>,
#  'BANK_SELECTION': <Concept - BANK_SELECTION>,
#  'BANKING_IND': <Concept - BANKING_IND>,
#  'BANKING_ITEM': <Concept - BANKING_ITEM>,
#  'BANKING_REF': <Concept - BANKING_REF>,
#  'BANKING_SUFFIX': <Concept - BANKING_SUFFIX>,
#  'BDS_ITEM': <Concept - BDS_ITEM>,
#  'BENCHMARK_ITEM': <Concept - BENCHMARK_ITEM>,
#  'BIS_BLOCK': <Concept - BIS_BLOCK>,
#  'BIS_SUFFIX': <Concept - BIS_SUFFIX>,
#  'BIS_TOPIC': <Concept - BIS_TOPIC>,
#  'BKN_DENOM': <Concept - BKN_DENOM>,
#  'BKN_ITEM': <Concept - BKN_ITEM>,
#  'BKN_SERIES': <Concept - BKN_SERIES>,
#  'BKN_TYPE': <Concept - BKN_TYPE>,
#  'BLS_AGG_METHOD': <Concept - BLS_AGG_METHOD>,
#  'BLS_COUNT': <Concept - BLS_COUNT>,
#  'BLS_COUNT_DETAIL': <Concept - BLS_COUNT_DETAIL>,
#  'BLS_ITEM': <Concept - BLS_ITEM>,
#  'BOP_BASIS': <Concept - BOP_BASIS>,
#  'BOP_ITEM': <Concept - BOP_ITEM>,
#  'BREAKS': <Concept - BREAKS>,
#  'BS_COUNT_SECTOR': <Concept - BS_COUNT_SECTOR>,
#  'BS_ITEM': <Concept - BS_ITEM>,
#  'BS_NFC_ACTIVITY': <Concept - BS_NFC_ACTIVITY>,
#  'BS_REP_SECTOR': <Concept - BS_REP_SECTOR>,
#  'BS_SUFFIX': <Concept - BS_SUFFIX>,
#  'CALCUL_END_DATE': <Concept - CALCUL_END_DATE>,
#  'CALCUL_START_DATE': <Concept - CALCUL_START_DATE>,
#  'CB_EXP_TYPE': <Concept - CB_EXP_TYPE>,
#  'CB_ITEM': <Concept - CB_ITEM>,
#  'CB_PORTFOLIO': <Concept - CB_PORTFOLIO>,
#  'CB_REP_FRAMEWRK': <Concept - CB_REP_FRAMEWRK>,
#  'CB_REP_SECTOR': <Concept - CB_REP_SECTOR>,
#  'CB_SECTOR_SIZE': <Concept - CB_SECTOR_SIZE>,
#  'CB_VAL_METHOD': <Concept - CB_VAL_METHOD>,
#  'CCP_SYSTEM': <Concept - CCP_SYSTEM>,
#  'CHNNL_CNSNT': <Concept - CHNNL_CNSNT>,
#  'CIBL_CATEGORY': <Concept - CIBL_CATEGORY>,
#  'CIBL_TABLE': <Concept - CIBL_TABLE>,
#  'CIBL_TYPE': <Concept - CIBL_TYPE>,
#  'COLLATERAL': <Concept - COLLATERAL>,
#  'COLLECTION': <Concept - COLLECTION>,
#  'COLLECTION_DETAIL': <Concept - COLLECTION_DETAIL>,
#  'COMMENT_OBS': <Concept - COMMENT_OBS>,
#  'COMMENT_TS': <Concept - COMMENT_TS>,
#  'COMP_APPROACH': <Concept - COMP_APPROACH>,
#  'COMP_METHOD': <Concept - COMP_METHOD>,
#  'COMPILATION': <Concept - COMPILATION>,
#  'COMPILING_ORG': <Concept - COMPILING_ORG>,
#  'CONF_STATUS': <Concept - CONF_STATUS>,
#  'COUNT_AREA': <Concept - COUNT_AREA>,
#  'COUNT_AREA_IFS': <Concept - COUNT_AREA_IFS>,
#  'COUNT_SECTOR': <Concept - COUNT_SECTOR>,
#  'COUNTERPART_AREA': <Concept - COUNTERPART_AREA>,
#  'COUNTERPART_SECTOR': <Concept - COUNTERPART_SECTOR>,
#  'COVERAGE': <Concept - COVERAGE>,
#  'COVERAGE_SECTOR': <Concept - COVERAGE_SECTOR>,
#  'CPP_METHOD': <Concept - CPP_METHOD>,
#  'CRD_FNCTN': <Concept - CRD_FNCTN>,
#  'CREDIT_RATING': <Concept - CREDIT_RATING>,
#  'CRISIS_ACC_MOTIV': <Concept - CRISIS_ACC_MOTIV>,
#  'CRISIS_MGMT_POLICY': <Concept - CRISIS_MGMT_POLICY>,
#  'CRISIS_TYPE': <Concept - CRISIS_TYPE>,
#  'CURR_BRKDWN': <Concept - CURR_BRKDWN>,
#  'CURRENCY': <Concept - CURRENCY>,
#  'CURRENCY_DENOM': <Concept - CURRENCY_DENOM>,
#  'CURRENCY_P_H': <Concept - CURRENCY_P_H>,
#  'CURRENCY_S': <Concept - CURRENCY_S>,
#  'CURRENCY_TRANS': <Concept - CURRENCY_TRANS>,
#  'DATA_COMP': <Concept - DATA_COMP>,
#  'DATA_PROVIDER': <Concept - DATA_PROVIDER>,
#  'DATA_TYPE': <Concept - DATA_TYPE>,
#  'DATA_TYPE_BKN': <Concept - DATA_TYPE_BKN>,
#  'DATA_TYPE_BOP': <Concept - DATA_TYPE_BOP>,
#  'DATA_TYPE_DBI': <Concept - DATA_TYPE_DBI>,
#  'DATA_TYPE_EST': <Concept - DATA_TYPE_EST>,
#  'DATA_TYPE_FM': <Concept - DATA_TYPE_FM>,
#  'DATA_TYPE_FXS': <Concept - DATA_TYPE_FXS>,
#  'DATA_TYPE_IFI': <Concept - DATA_TYPE_IFI>,
#  'DATA_TYPE_LIG': <Concept - DATA_TYPE_LIG>,
#  'DATA_TYPE_MIR': <Concept - DATA_TYPE_MIR>,
#  'DATA_TYPE_MM': <Concept - DATA_TYPE_MM>,
#  'DATA_TYPE_MUFA': <Concept - DATA_TYPE_MUFA>,
#  'DATA_TYPE_PDF': <Concept - DATA_TYPE_PDF>,
#  'DATA_TYPE_PSS': <Concept - DATA_TYPE_PSS>,
#  'DATA_TYPE_SEC': <Concept - DATA_TYPE_SEC>,
#  'DD_ECON_CONCEPT': <Concept - DD_ECON_CONCEPT>,
#  'DD_SUFFIX': <Concept - DD_SUFFIX>,
#  'DD_TRANSF': <Concept - DD_TRANSF>,
#  'DEBT_TYPE': <Concept - DEBT_TYPE>,
#  'DECIMALS': <Concept - DECIMALS>,
#  'DISS_ORG': <Concept - DISS_ORG>,
#  'DOM_SER_IDS': <Concept - DOM_SER_IDS>,
#  'EAPLUS_FLAG': <Concept - EAPLUS_FLAG>,
#  'EFFECT_DOMAIN': <Concept - EFFECT_DOMAIN>,
#  'EMBARGO': <Concept - EMBARGO>,
#  'EMBARGO_DETAIL': <Concept - EMBARGO_DETAIL>,
#  'END_DATE': <Concept - END_DATE>,
#  'EONIA_BANK': <Concept - EONIA_BANK>,
#  'EONIA_ITEM': <Concept - EONIA_ITEM>,
#  'ESA95_ACCOUNT': <Concept - ESA95_ACCOUNT>,
#  'ESA95_BREAKDOWN': <Concept - ESA95_BREAKDOWN>,
#  'ESA95_SUFFIX': <Concept - ESA95_SUFFIX>,
#  'ESA95_UNIT': <Concept - ESA95_UNIT>,
#  'ESA95TP_ASSET': <Concept - ESA95TP_ASSET>,
#  'ESA95TP_BRKDWN': <Concept - ESA95TP_BRKDWN>,
#  'ESA95TP_COM': <Concept - ESA95TP_COM>,
#  'ESA95TP_CONS': <Concept - ESA95TP_CONS>,
#  'ESA95TP_CPAREA': <Concept - ESA95TP_CPAREA>,
#  'ESA95TP_CPSECTOR': <Concept - ESA95TP_CPSECTOR>,
#  'ESA95TP_DC_AL': <Concept - ESA95TP_DC_AL>,
#  'ESA95TP_DENOM': <Concept - ESA95TP_DENOM>,
#  'ESA95TP_PRICE': <Concept - ESA95TP_PRICE>,
#  'ESA95TP_REGION': <Concept - ESA95TP_REGION>,
#  'ESA95TP_SECTOR': <Concept - ESA95TP_SECTOR>,
#  'ESA95TP_SUFFIX': <Concept - ESA95TP_SUFFIX>,
#  'ESA95TP_TRANS': <Concept - ESA95TP_TRANS>,
#  'ESCB_FLAG': <Concept - ESCB_FLAG>,
#  'EVENT_DESCR': <Concept - EVENT_DESCR>,
#  'EVENT_HIST': <Concept - EVENT_HIST>,
#  'EXR_SUFFIX': <Concept - EXR_SUFFIX>,
#  'EXR_TYPE': <Concept - EXR_TYPE>,
#  'EXT_REF_AREA': <Concept - EXT_REF_AREA>,
#  'EXT_TITLE': <Concept - EXT_TITLE>,
#  'EXT_UNIT': <Concept - EXT_UNIT>,
#  'EXT_UNIT_MULT': <Concept - EXT_UNIT_MULT>,
#  'FCT_BREAKDOWN': <Concept - FCT_BREAKDOWN>,
#  'FCT_HORIZON': <Concept - FCT_HORIZON>,
#  'FCT_SOURCE': <Concept - FCT_SOURCE>,
#  'FCT_TOPIC': <Concept - FCT_TOPIC>,
#  'FIRM_AGE': <Concept - FIRM_AGE>,
#  'FIRM_OWNERSHIP': <Concept - FIRM_OWNERSHIP>,
#  'FIRM_SECTOR': <Concept - FIRM_SECTOR>,
#  'FIRM_SIZE': <Concept - FIRM_SIZE>,
#  'FIRM_TURNOVER': <Concept - FIRM_TURNOVER>,
#  'FLOATING_RATE_BASE': <Concept - FLOATING_RATE_BASE>,
#  'FLOW_STOCK_ENTRY': <Concept - FLOW_STOCK_ENTRY>,
#  'FM_CONTRACT_TIME': <Concept - FM_CONTRACT_TIME>,
#  'FM_COUPON_RATE': <Concept - FM_COUPON_RATE>,
#  'FM_IDENTIFIER': <Concept - FM_IDENTIFIER>,
#  'FM_LOT_SIZE': <Concept - FM_LOT_SIZE>,
#  'FM_MATURITY': <Concept - FM_MATURITY>,
#  'FM_OUTS_AMOUNT': <Concept - FM_OUTS_AMOUNT>,
#  'FM_PUT_CALL': <Concept - FM_PUT_CALL>,
#  'FM_STRIKE_PRICE': <Concept - FM_STRIKE_PRICE>,
#  'FRD_TYP': <Concept - FRD_TYP>,
#  'FREQ': <Concept - FREQ>,
#  'FUNCTIONAL_CAT': <Concept - FUNCTIONAL_CAT>,
#  'FVC_ITEM': <Concept - FVC_ITEM>,
#  'FVC_ORI_SECTOR': <Concept - FVC_ORI_SECTOR>,
#  'FVC_REP_SECTOR': <Concept - FVC_REP_SECTOR>,
#  'FXS_OP_TYPE': <Concept - FXS_OP_TYPE>,
#  'GOVNT_COUNT_SECTOR': <Concept - GOVNT_COUNT_SECTOR>,
#  'GOVNT_ITEM_ESA': <Concept - GOVNT_ITEM_ESA>,
#  'GOVNT_REF_SECTOR': <Concept - GOVNT_REF_SECTOR>,
#  'GOVNT_ST_SUFFIX': <Concept - GOVNT_ST_SUFFIX>,
#  'GOVNT_VALUATION': <Concept - GOVNT_VALUATION>,
#  'GROUP_TYPE': <Concept - GROUP_TYPE>,
#  'HOLDER_AREA': <Concept - HOLDER_AREA>,
#  'HOLDER_SECTOR': <Concept - HOLDER_SECTOR>,
#  'ICO_PAY': <Concept - ICO_PAY>,
#  'ICO_UNIT': <Concept - ICO_UNIT>,
#  'ICP_ITEM': <Concept - ICP_ITEM>,
#  'ICP_SUFFIX': <Concept - ICP_SUFFIX>,
#  'ICPF_ITEM': <Concept - ICPF_ITEM>,
#  'IFS_CODE': <Concept - IFS_CODE>,
#  'IN_OUT_DATA_IFI': <Concept - IN_OUT_DATA_IFI>,
#  'INDICATOR': <Concept - INDICATOR>,
#  'INS_BUS_TYPE': <Concept - INS_BUS_TYPE>,
#  'INSTR_ASSET': <Concept - INSTR_ASSET>,
#  'INSTR_TYPE_MMSR': <Concept - INSTR_TYPE_MMSR>,
#  'INSTRUMENT_FM': <Concept - INSTRUMENT_FM>,
#  'INT_ACC_ITEM': <Concept - INT_ACC_ITEM>,
#  'INTTN_CHNNL': <Concept - INTTN_CHNNL>,
#  'IR_BUS_COV': <Concept - IR_BUS_COV>,
#  'IR_FV_TYPE': <Concept - IR_FV_TYPE>,
#  'IR_TYPE': <Concept - IR_TYPE>,
#  'IS_IN_EADB': <Concept - IS_IN_EADB>,
#  'ISSUER_AREA': <Concept - ISSUER_AREA>,
#  'ISSUER_IN': <Concept - ISSUER_IN>,
#  'ISSUER_RBG': <Concept - ISSUER_RBG>,
#  'ISSUER_SECTOR': <Concept - ISSUER_SECTOR>,
#  'IVF_ITEM': <Concept - IVF_ITEM>,
#  'IVF_REP_SECTOR': <Concept - IVF_REP_SECTOR>,
#  'LBLTY_BRR': <Concept - LBLTY_BRR>,
#  'LIG_ITEM': <Concept - LIG_ITEM>,
#  'MA_FLAG': <Concept - MA_FLAG>,
#  'MACROPRU_EXPL': <Concept - MACROPRU_EXPL>,
#  'MARKET_ROLE': <Concept - MARKET_ROLE>,
#  'MARKET_TRANS': <Concept - MARKET_TRANS>,
#  'MATURITY': <Concept - MATURITY>,
#  'MATURITY_CAT': <Concept - MATURITY_CAT>,
#  'MATURITY_NOT_IRATE': <Concept - MATURITY_NOT_IRATE>,
#  'MATURITY_ORIG': <Concept - MATURITY_ORIG>,
#  'MATURITY_RES': <Concept - MATURITY_RES>,
#  'MATURITY_TYPE': <Concept - MATURITY_TYPE>,
#  'MEASURE_DATE': <Concept - MEASURE_DATE>,
#  'MEASURE_MEI': <Concept - MEASURE_MEI>,
#  'MEASURE_QNA': <Concept - MEASURE_QNA>,
#  'MEASURE_SNA': <Concept - MEASURE_SNA>,
#  'METHOD_AGENCY': <Concept - METHOD_AGENCY>,
#  'METHOD_DETAIL': <Concept - METHOD_DETAIL>,
#  'METHOD_PUBL': <Concept - METHOD_PUBL>,
#  'METHOD_REF': <Concept - METHOD_REF>,
#  'MFI_LIST': <Concept - MFI_LIST>,
#  'MFI_LIST_IND': <Concept - MFI_LIST_IND>,
#  'MFI_STATUS': <Concept - MFI_STATUS>,
#  'MM_BANK': <Concept - MM_BANK>,
#  'MM_SEGMENT': <Concept - MM_SEGMENT>,
#  'MODEL_ASSUMP_ERR': <Concept - MODEL_ASSUMP_ERR>,
#  'MRCHNT_CTGRY_CD': <Concept - MRCHNT_CTGRY_CD>,
#  'MUFA_CRED_AREA': <Concept - MUFA_CRED_AREA>,
#  'MUFA_CRED_SECTOR': <Concept - MUFA_CRED_SECTOR>,
#  'MUFA_DEBT_AREA': <Concept - MUFA_DEBT_AREA>,
#  'MUFA_DEBT_SECTOR': <Concept - MUFA_DEBT_SECTOR>,
#  'MUFA_ITEM': <Concept - MUFA_ITEM>,
#  'MUFA_SOURCE': <Concept - MUFA_SOURCE>,
#  'MUFA_VALUATION': <Concept - MUFA_VALUATION>,
#  'NA_PRICE': <Concept - NA_PRICE>,
#  'NAT_TITLE': <Concept - NAT_TITLE>,
#  'NOM_CURR': <Concept - NOM_CURR>,
#  'NON_RESID_ECON_ACT': <Concept - NON_RESID_ECON_ACT>,
#  'OBS_COM': <Concept - OBS_COM>,
#  'OBS_CONF': <Concept - OBS_CONF>,
#  'OBS_PRE_BREAK': <Concept - OBS_PRE_BREAK>,
#  'OBS_STATUS': <Concept - OBS_STATUS>,
#  'OBS_VALUE': <Concept - OBS_VALUE>,
#  'OECD_A16_CODE': <Concept - OECD_A16_CODE>,
#  'OEO_CODE': <Concept - OEO_CODE>,
#  'OFI_ITEM': <Concept - OFI_ITEM>,
#  'OFI_REP_SECTOR': <Concept - OFI_REP_SECTOR>,
#  'OIL_PRODUCT': <Concept - OIL_PRODUCT>,
#  'OLV_INDICATOR': <Concept - OLV_INDICATOR>,
#  'OPTION_TYPE_PDF': <Concept - OPTION_TYPE_PDF>,
#  'ORGANISATION': <Concept - ORGANISATION>,
#  'OTHER_METH_EXPL': <Concept - OTHER_METH_EXPL>,
#  'PD_ITEM': <Concept - PD_ITEM>,
#  'PD_ORIGIN': <Concept - PD_ORIGIN>,
#  'PD_SEAS_EX': <Concept - PD_SEAS_EX>,
#  'PF_MEMBER_TYPE': <Concept - PF_MEMBER_TYPE>,
#  'PORTFOLIO_CAT': <Concept - PORTFOLIO_CAT>,
#  'PRE_BREAK_VALUE': <Concept - PRE_BREAK_VALUE>,
#  'PRICE_BASE': <Concept - PRICE_BASE>,
#  'PRICE_TYPE': <Concept - PRICE_TYPE>,
#  'PRJ_PER_HORIZON': <Concept - PRJ_PER_HORIZON>,
#  'PRJ_QUARTER': <Concept - PRJ_QUARTER>,
#  'PROPERTY_CPP': <Concept - PROPERTY_CPP>,
#  'PROPERTY_IND': <Concept - PROPERTY_IND>,
#  'PROPERTY_SUFFIX': <Concept - PROPERTY_SUFFIX>,
#  'PROPERTY_TYPE': <Concept - PROPERTY_TYPE>,
#  'PROVIDER_FM': <Concept - PROVIDER_FM>,
#  'PROVIDER_FM_ID': <Concept - PROVIDER_FM_ID>,
#  'PRTC_INSTTL_SCTR': <Concept - PRTC_INSTTL_SCTR>,
#  'PRTCPTN': <Concept - PRTCPTN>,
#  'PSP_CTGRY': <Concept - PSP_CTGRY>,
#  'PSS_INFO_TYPE': <Concept - PSS_INFO_TYPE>,
#  'PSS_INSTRUMENT': <Concept - PSS_INSTRUMENT>,
#  'PSS_SYSTEM': <Concept - PSS_SYSTEM>,
#  'PUBL_ECB': <Concept - PUBL_ECB>,
#  'PUBL_MU': <Concept - PUBL_MU>,
#  'PUBL_PUBLIC': <Concept - PUBL_PUBLIC>,
#  'PYMNT_SCHM': <Concept - PYMNT_SCHM>,
#  'PYMNT_SYSTM': <Concept - PYMNT_SYSTM>,
#  'R_L_SECTOR': <Concept - R_L_SECTOR>,
#  'RBG_ID': <Concept - RBG_ID>,
#  'RECOVERY_DATE': <Concept - RECOVERY_DATE>,
#  'REF_AREA': <Concept - REF_AREA>,
#  'REF_AREA_MEI': <Concept - REF_AREA_MEI>,
#  'REF_PERIOD_DETAIL': <Concept - REF_PERIOD_DETAIL>,
#  'REF_SECTOR': <Concept - REF_SECTOR>,
#  'REGION': <Concept - REGION>,
#  'REP_CTY': <Concept - REP_CTY>,
#  'REP_DELAY': <Concept - REP_DELAY>,
#  'REPO_CPARTY': <Concept - REPO_CPARTY>,
#  'REPORTING_SECTOR': <Concept - REPORTING_SECTOR>,
#  'RESID_ECON_ACT': <Concept - RESID_ECON_ACT>,
#  'RIR_SUFFIX': <Concept - RIR_SUFFIX>,
#  'RL_TRNSCTN': <Concept - RL_TRNSCTN>,
#  'RMT_INTTN': <Concept - RMT_INTTN>,
#  'RPP_DWELLING': <Concept - RPP_DWELLING>,
#  'RPP_GEO_COV': <Concept - RPP_GEO_COV>,
#  'RPP_SOURCE': <Concept - RPP_SOURCE>,
#  'RPP_SUFFIX': <Concept - RPP_SUFFIX>,
#  'RT_DENOM': <Concept - RT_DENOM>,
#  'RT_ECON_CONCEPT': <Concept - RT_ECON_CONCEPT>,
#  'SAFE_ANSWER': <Concept - SAFE_ANSWER>,
#  'SAFE_DENOM': <Concept - SAFE_DENOM>,
#  'SAFE_FILTER': <Concept - SAFE_FILTER>,
#  'SAFE_ITEM': <Concept - SAFE_ITEM>,
#  'SAFE_QUESTION': <Concept - SAFE_QUESTION>,
#  'SBS_BREAKDOWN': <Concept - SBS_BREAKDOWN>,
#  'SBS_DI_1': <Concept - SBS_DI_1>,
#  'SBS_DI_2': <Concept - SBS_DI_2>,
#  'SBS_SAMPLE_TYPE': <Concept - SBS_SAMPLE_TYPE>,
#  'SCA': <Concept - SCA>,
#  'SEC_ISSUING_SECTOR': <Concept - SEC_ISSUING_SECTOR>,
#  'SEC_ITEM': <Concept - SEC_ITEM>,
#  'SEC_SUFFIX': <Concept - SEC_SUFFIX>,
#  'SEC_VALUATION': <Concept - SEC_VALUATION>,
#  'SECURITISATION_TYP': <Concept - SECURITISATION_TYP>,
#  'SECURITY_TYPE': <Concept - SECURITY_TYPE>,
#  'SEE_SYSTEM': <Concept - SEE_SYSTEM>,
#  'SERIES_DENOM': <Concept - SERIES_DENOM>,
#  'SHI_INDICATOR': <Concept - SHI_INDICATOR>,
#  'SHI_SUFFIX': <Concept - SHI_SUFFIX>,
#  'SOURCE_AGENCY': <Concept - SOURCE_AGENCY>,
#  'SOURCE_AGENCY_2': <Concept - SOURCE_AGENCY_2>,
#  'SOURCE_DATA': <Concept - SOURCE_DATA>,
#  'SOURCE_DETAIL': <Concept - SOURCE_DETAIL>,
#  'SOURCE_DETAIL_2': <Concept - SOURCE_DETAIL_2>,
#  'SOURCE_PUB': <Concept - SOURCE_PUB>,
#  'SOURCE_PUBL_2': <Concept - SOURCE_PUBL_2>,
#  'SSI_INDICATOR': <Concept - SSI_INDICATOR>,
#  'SSS_INFO_TYPE': <Concept - SSS_INFO_TYPE>,
#  'SSS_INSTRUMENT': <Concept - SSS_INSTRUMENT>,
#  'SSS_SYSTEM': <Concept - SSS_SYSTEM>,
#  'START_DATE': <Concept - START_DATE>,
#  'STO': <Concept - STO>,
#  'STOCK_FLOW': <Concept - STOCK_FLOW>,
#  'STS_CLASS': <Concept - STS_CLASS>,
#  'STS_CONCEPT': <Concept - STS_CONCEPT>,
#  'STS_INSTITUTION': <Concept - STS_INSTITUTION>,
#  'STS_SUFFIX': <Concept - STS_SUFFIX>,
#  'SUBJECT_MEI': <Concept - SUBJECT_MEI>,
#  'SUBJECT_OEO': <Concept - SUBJECT_OEO>,
#  'SUBJECT_QNA': <Concept - SUBJECT_QNA>,
#  'SUBJECT_SNA': <Concept - SUBJECT_SNA>,
#  'SUFFIX_QNA': <Concept - SUFFIX_QNA>,
#  'SURVEY_BRKDWN': <Concept - SURVEY_BRKDWN>,
#  'SURVEY_FREQ': <Concept - SURVEY_FREQ>,
#  'SURVEY_ITEM': <Concept - SURVEY_ITEM>,
#  'SURVEY_ROUND': <Concept - SURVEY_ROUND>,
#  'SURVEY_SOURCE': <Concept - SURVEY_SOURCE>,
#  'TIME_FORMAT': <Concept - TIME_FORMAT>,
#  'TIME_HORIZON': <Concept - TIME_HORIZON>,
#  'TIME_PER_COLLECT': <Concept - TIME_PER_COLLECT>,
#  'TIME_PERIOD': <Concept - TIME_PERIOD>,
#  'TITLE': <Concept - TITLE>,
#  'TITLE_COMPL': <Concept - TITLE_COMPL>,
#  'TPH': <Concept - TPH>,
#  'TR_TYPE': <Concept - TR_TYPE>,
#  'TRADE_WEIGHT': <Concept - TRADE_WEIGHT>,
#  'TRANS_TYPE_MMSR': <Concept - TRANS_TYPE_MMSR>,
#  'TRANSFORMATION': <Concept - TRANSFORMATION>,
#  'TRD_FLOW': <Concept - TRD_FLOW>,
#  'TRD_PRODUCT': <Concept - TRD_PRODUCT>,
#  'TRD_SUFFIX': <Concept - TRD_SUFFIX>,
#  'TRG_ACCOUNT': <Concept - TRG_ACCOUNT>,
#  'TRG_ANCILLARY': <Concept - TRG_ANCILLARY>,
#  'TRG_BAND': <Concept - TRG_BAND>,
#  'TRG_CATEGORY': <Concept - TRG_CATEGORY>,
#  'TRMNL_FNCTN': <Concept - TRMNL_FNCTN>,
#  'TRMNL_LCTN': <Concept - TRMNL_LCTN>,
#  'TYP_INFO': <Concept - TYP_INFO>,
#  'TYP_TRNSCTN': <Concept - TYP_TRNSCTN>,
#  'U_A_SECTOR': <Concept - U_A_SECTOR>,
#  'UNIT': <Concept - UNIT>,
#  'UNIT_DETAIL': <Concept - UNIT_DETAIL>,
#  'UNIT_INDEX_BASE': <Concept - UNIT_INDEX_BASE>,
#  'UNIT_MEASURE': <Concept - UNIT_MEASURE>,
#  'UNIT_MULT': <Concept - UNIT_MULT>,
#  'UNIT_PRICE_BASE': <Concept - UNIT_PRICE_BASE>,
#  'VALUATION': <Concept - VALUATION>,
#  'VIS_CTY': <Concept - VIS_CTY>,
#  'WEO_ITEM': <Concept - WEO_ITEM>,
#  'WEO_REF_AREA': <Concept - WEO_REF_AREA>,
#  'WOB_CONCEPT': <Concept - WOB_CONCEPT>,
#  'WOB_TAXATION': <Concept - WOB_TAXATION>}

# %%
dsd = message.content['dsds']['ECB:ECB_CBD2(1.0)']
dsd.content
# Out:
# {'dimensions': {'FREQ': <Dimension - FREQ>,
#   'REF_AREA': <Dimension - REF_AREA>,
#   'COUNT_AREA': <Dimension - COUNT_AREA>,
#   'CB_REP_SECTOR': <Dimension - CB_REP_SECTOR>,
#   'BS_COUNT_SECTOR': <Dimension - BS_COUNT_SECTOR>,
#   'BS_NFC_ACTIVITY': <Dimension - BS_NFC_ACTIVITY>,
#   'CB_SECTOR_SIZE': <Dimension - CB_SECTOR_SIZE>,
#   'CB_REP_FRAMEWRK': <Dimension - CB_REP_FRAMEWRK>,
#   'CB_ITEM': <Dimension - CB_ITEM>,
#   'CB_PORTFOLIO': <Dimension - CB_PORTFOLIO>,
#   'CB_EXP_TYPE': <Dimension - CB_EXP_TYPE>,
#   'CB_VAL_METHOD': <Dimension - CB_VAL_METHOD>,
#   'MATURITY_RES': <Dimension - MATURITY_RES>,
#   'DATA_TYPE': <Dimension - DATA_TYPE>,
#   'CURRENCY_TRANS': <Dimension - CURRENCY_TRANS>,
#   'UNIT_MEASURE': <Dimension - UNIT_MEASURE>,
#   'TIME_PERIOD': <TimeDimension - TIME_PERIOD>},
#  'measure': <PrimaryMeasure - OBS_VALUE>,
#  'attributes': {'TIME_FORMAT': <Attribute - TIME_FORMAT>,
#   'OBS_STATUS': <Attribute - OBS_STATUS>,
#   'CONF_STATUS': <Attribute - CONF_STATUS>,
#   'PRE_BREAK_VALUE': <Attribute - PRE_BREAK_VALUE>,
#   'COMMENT_OBS': <Attribute - COMMENT_OBS>,
#   'BREAKS': <Attribute - BREAKS>,
#   'COMMENT_TS': <Attribute - COMMENT_TS>,
#   'COMPILING_ORG': <Attribute - COMPILING_ORG>,
#   'COVERAGE': <Attribute - COVERAGE>,
#   'CURRENCY': <Attribute - CURRENCY>,
#   'DATA_COMP': <Attribute - DATA_COMP>,
#   'DECIMALS': <Attribute - DECIMALS>,
#   'DISS_ORG': <Attribute - DISS_ORG>,
#   'PUBL_ECB': <Attribute - PUBL_ECB>,
#   'PUBL_MU': <Attribute - PUBL_MU>,
#   'PUBL_PUBLIC': <Attribute - PUBL_PUBLIC>,
#   'TIME_PER_COLLECT': <Attribute - TIME_PER_COLLECT>,
#   'TITLE': <Attribute - TITLE>,
#   'TITLE_COMPL': <Attribute - TITLE_COMPL>,
#   'UNIT_MULT': <Attribute - UNIT_MULT>}}

# %%
freq = dsd.content['dimensions']['FREQ']

# %%
freq.concept_identity
# Out:
# <Concept - FREQ>

# %%
freq.representation
# Out:
# <Representation - [<minLength - 1>, <maxLength - 1>] - String>

# %%
print(freq.concept_identity.core_representation)
# Out:
# None

# %%
freq.local_representation.codelist
# Out:
# <Codelist - CL_FREQ>

# %%
freq.local_representation.codelist.items
# Out:
# {'A': <Code - A>,
#  'B': <Code - B>,
#  'D': <Code - D>,
#  'E': <Code - E>,
#  'H': <Code - H>,
#  'M': <Code - M>,
#  'N': <Code - N>,
#  'Q': <Code - Q>,
#  'S': <Code - S>,
#  'W': <Code - W>}

# %% [markdown]
# ### Metadata creation and manipulation

# %%
name = InternationalString()
name.addLocalisedString(LocalisedString('English', 'en', 'NEW_CONCEPT'))
concept = Concept('NEW_CONCEPT', name=name)

# %%
concept_scheme.append(concept)
concept_scheme.items
# Out:
# {'ADJUST_CODED': <Concept - ADJUST_CODED>,
#  'AVAILABILITY': <Concept - AVAILABILITY>,
#  'BIS_BLOCK': <Concept - BIS_BLOCK>,
#  'BIS_UNIT': <Concept - BIS_UNIT>,
#  'BORROWERS_CTY': <Concept - BORROWERS_CTY>,
#  'BREAKS': <Concept - BREAKS>,
#  'CBS_BANK_TYPE': <Concept - CBS_BANK_TYPE>,
#  'CBS_BASIS': <Concept - CBS_BASIS>,
#  'CG_DTYPE': <Concept - CG_DTYPE>,
#  'CIBL_CATEGORY': <Concept - CIBL_CATEGORY>,
#  'CIBL_TABLE': <Concept - CIBL_TABLE>,
#  'CIBL_TYPE': <Concept - CIBL_TYPE>,
#  'COLLECTION': <Concept - COLLECTION>,
#  'COLLECTION_DETAIL': <Concept - COLLECTION_DETAIL>,
#  'COMPILING_ORG': <Concept - COMPILING_ORG>,
#  'COVERAGE': <Concept - COVERAGE>,
#  'COVERED_AREA': <Concept - COVERED_AREA>,
#  'CURR_TYPE_BOOK': <Concept - CURR_TYPE_BOOK>,
#  'DATA_COMP': <Concept - DATA_COMP>,
#  'DECIMALS': <Concept - DECIMALS>,
#  'DOC_METHOD': <Concept - DOC_METHOD>,
#  'DSR_BORROWERS': <Concept - DSR_BORROWERS>,
#  'EER_BASKET': <Concept - EER_BASKET>,
#  'EER_TYPE': <Concept - EER_TYPE>,
#  'FREQ': <Concept - FREQ>,
#  'IBLN_CATEGORY': <Concept - IBLN_CATEGORY>,
#  'IBLN_TABLE': <Concept - IBLN_TABLE>,
#  'IBLN_TYPE': <Concept - IBLN_TYPE>,
#  'IBLR_CATEGORY': <Concept - IBLR_CATEGORY>,
#  'IBLR_CURR': <Concept - IBLR_CURR>,
#  'IBLR_TYPE': <Concept - IBLR_TYPE>,
#  'ISSUE_COL': <Concept - ISSUE_COL>,
#  'ISSUE_CUR': <Concept - ISSUE_CUR>,
#  'ISSUE_CUR_GROUP': <Concept - ISSUE_CUR_GROUP>,
#  'ISSUE_OR_MAT': <Concept - ISSUE_OR_MAT>,
#  'ISSUE_RATE': <Concept - ISSUE_RATE>,
#  'ISSUE_RE_MAT': <Concept - ISSUE_RE_MAT>,
#  'ISSUE_RISK': <Concept - ISSUE_RISK>,
#  'ISSUE_TYPE': <Concept - ISSUE_TYPE>,
#  'ISSUER_BUS_IMM': <Concept - ISSUER_BUS_IMM>,
#  'ISSUER_BUS_ULT': <Concept - ISSUER_BUS_ULT>,
#  'ISSUER_NAT': <Concept - ISSUER_NAT>,
#  'ISSUER_RES': <Concept - ISSUER_RES>,
#  'L_DENOM': <Concept - L_DENOM>,
#  'L_INSTR': <Concept - L_INSTR>,
#  'L_MEASURE': <Concept - L_MEASURE>,
#  'L_POSITION': <Concept - L_POSITION>,
#  'L_REP_BANK_TYPE': <Concept - L_REP_BANK_TYPE>,
#  'L_CURR_TYPE': <Concept - L_CURR_TYPE>,
#  'L_PARENT_CTY': <Concept - L_PARENT_CTY>,
#  'L_POS_TYPE': <Concept - L_POS_TYPE>,
#  'L_REP_CTY': <Concept - L_REP_CTY>,
#  'L_CP_COUNTRY': <Concept - L_CP_COUNTRY>,
#  'L_CP_SECTOR': <Concept - L_CP_SECTOR>,
#  'MARKET': <Concept - MARKET>,
#  'MEASURE': <Concept - MEASURE>,
#  'MEASURE_DETAIL': <Concept - MEASURE_DETAIL>,
#  'META_UPDATE': <Concept - META_UPDATE>,
#  'OBS_CONF': <Concept - OBS_CONF>,
#  'OBS_PRE_BREAK': <Concept - OBS_PRE_BREAK>,
#  'OBS_STATUS': <Concept - OBS_STATUS>,
#  'OBS_VALUE': <Concept - OBS_VALUE>,
#  'OD_INSTR': <Concept - OD_INSTR>,
#  'OD_RISK_CAT': <Concept - OD_RISK_CAT>,
#  'OD_TYPE': <Concept - OD_TYPE>,
#  'ORG_VISIBILITY': <Concept - ORG_VISIBILITY>,
#  'PRICED_UNIT': <Concept - PRICED_UNIT>,
#  'PUBLICATIONS': <Concept - PUBLICATIONS>,
#  'REF_AREA': <Concept - REF_AREA>,
#  'REM_MATURITY': <Concept - REM_MATURITY>,
#  'REP_CTY': <Concept - REP_CTY>,
#  'RE_TYPE': <Concept - RE_TYPE>,
#  'RE_VINTAGE': <Concept - RE_VINTAGE>,
#  'SOURCE_TYPE': <Concept - SOURCE_TYPE>,
#  'TC_ADJUST': <Concept - TC_ADJUST>,
#  'TC_BORROWERS': <Concept - TC_BORROWERS>,
#  'TC_LENDERS': <Concept - TC_LENDERS>,
#  'TIME_FORMAT': <Concept - TIME_FORMAT>,
#  'TIME_PERIOD': <Concept - TIME_PERIOD>,
#  'TITLE_GRP': <Concept - TITLE_GRP>,
#  'TITLE_GRP_COMPL': <Concept - TITLE_GRP_COMPL>,
#  'TITLE_GRP_NAT': <Concept - TITLE_GRP_NAT>,
#  'TITLE_TS': <Concept - TITLE_TS>,
#  'UNIT_MEASURE': <Concept - UNIT_MEASURE>,
#  'UNIT_MULT': <Concept - UNIT_MULT>,
#  'UNIT_TYPE': <Concept - UNIT_TYPE>,
#  'VALUE': <Concept - VALUE>,
#  'VALUATION': <Concept - VALUATION>,
#  'VIS_CTY': <Concept - VIS_CTY>,
#  'XD_EXCHANGE': <Concept - XD_EXCHANGE>,
#  'OD_CPARTY': <Concept - OD_CPARTY>,
#  'OD_REP_CTY': <Concept - OD_REP_CTY>,
#  'OD_CURR_MAT_REG': <Concept - OD_CURR_MAT_REG>,
#  'DER_TYPE': <Concept - DER_TYPE>,
#  'DER_INSTR': <Concept - DER_INSTR>,
#  'DER_RISK': <Concept - DER_RISK>,
#  'DER_REP_CTY': <Concept - DER_REP_CTY>,
#  'DER_SECTOR_CPY': <Concept - DER_SECTOR_CPY>,
#  'DER_CPC': <Concept - DER_CPC>,
#  'DER_SECTOR_UDL': <Concept - DER_SECTOR_UDL>,
#  'DER_CURR_LEG1': <Concept - DER_CURR_LEG1>,
#  'DER_CURR_LEG2': <Concept - DER_CURR_LEG2>,
#  'DER_ISSUE_MAT': <Concept - DER_ISSUE_MAT>,
#  'DER_RATING': <Concept - DER_RATING>,
#  'DER_EX_METHOD': <Concept - DER_EX_METHOD>,
#  'DER_BASIS': <Concept - DER_BASIS>,
#  'CURR_DENOM': <Concept - CURR_DENOM>,
#  'LENDERS_SECTOR': <Concept - LENDERS_SECTOR>,
#  'BORROWERS_SECTOR': <Concept - BORROWERS_SECTOR>,
#  'CURRENCY': <Concept - CURRENCY>,
#  'TITLE': <Concept - TITLE>,
#  'NEW_CONCEPT': <Concept - NEW_CONCEPT>}

# %%
dimension = Dimension('NEW_DIMENSION', position=16)
dimension.concept_identity = concept

# %%
dsd.dimension_descriptor.add_component(dimension)
dsd.content
# Out:
# {'dimensions': {'FREQ': <Dimension - FREQ>,
#   'DER_TYPE': <Dimension - DER_TYPE>,
#   'DER_INSTR': <Dimension - DER_INSTR>,
#   'DER_RISK': <Dimension - DER_RISK>,
#   'DER_REP_CTY': <Dimension - DER_REP_CTY>,
#   'DER_SECTOR_CPY': <Dimension - DER_SECTOR_CPY>,
#   'DER_CPC': <Dimension - DER_CPC>,
#   'DER_SECTOR_UDL': <Dimension - DER_SECTOR_UDL>,
#   'DER_CURR_LEG1': <Dimension - DER_CURR_LEG1>,
#   'DER_CURR_LEG2': <Dimension - DER_CURR_LEG2>,
#   'DER_ISSUE_MAT': <Dimension - DER_ISSUE_MAT>,
#   'DER_RATING': <Dimension - DER_RATING>,
#   'DER_EX_METHOD': <Dimension - DER_EX_METHOD>,
#   'DER_BASIS': <Dimension - DER_BASIS>,
#   'TIME_PERIOD': <TimeDimension - TIME_PERIOD>,
#   'NEW_DIMENSION': <Dimension - NEW_DIMENSION>},
#  'measure': <PrimaryMeasure - OBS_VALUE>,
#  'attributes': {'TIME_FORMAT': <Attribute - TIME_FORMAT>,
#   'OBS_STATUS': <Attribute - OBS_STATUS>,
#   'AVAILABILITY': <Attribute - AVAILABILITY>,
#   'COLLECTION': <Attribute - COLLECTION>,
#   'DECIMALS': <Attribute - DECIMALS>,
#   'UNIT_MEASURE': <Attribute - UNIT_MEASURE>,
#   'UNIT_MULT': <Attribute - UNIT_MULT>,
#   'OBS_CONF': <Attribute - OBS_CONF>,
#   'OBS_PRE_BREAK': <Attribute - OBS_PRE_BREAK>,
#   'TITLE_TS': <Attribute - TITLE_TS>},
#  'groups': <GroupDimensionDescriptor - Sibling>}

# %%
message.to_xml()
